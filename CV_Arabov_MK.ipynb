# %% [markdown]
# <a href="https://colab.research.google.com/github/CodeHunterOfficial/SimpleRepo/blob/main/CV_Arabov_MK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 🧑‍💻 **Mulosharaf Kurbonovich Arabov**
#
# 📍 **Location:** Kazan, Russia
# 📧 **Email:** *cool.araby@gmail.com*
# 📱 **Telegram:** [@cool_araby](https://t.me/cool_araby) | **VK:** [cool.araby](https://vk.com/cool.araby)
# 🔗 **Profiles:** [GitHub](https://github.com/CodeHunterOfficial) | [HuggingFace](https://huggingface.co/ArabovMK) | [Google Scholar](https://scholar.google.ru/citations?hl=ru&user=2ljbCVIAAAAJ) | [Scopus](https://www.scopus.com/authid/detail.uri?authorId=57199509352) | [eLibrary.ru](https://elibrary.ru/author_items.asp?authorid=849030)
#
# ### **Objective**
# To contribute to cutting-edge AI and Data Science research at KAUST by leveraging my interdisciplinary expertise in mathematical modeling, machine learning, natural language processing (NLP), and applied mathematics.
#
#
# ### 🎓 **Academic Background**
# **PhD in Mathematical Sciences** (2016)
# Institute of Mathematics named after A. Dzhuraev, Academy of Sciences of the Republic of Tajikistan
# - **Dissertation:** *“Study of Periodic Oscillations and Stability Analysis of Solutions to Second-Order Differential Equations with Piecewise Linear Right-Hand Sides”*
#
# **Tajik National University**
# **Bachelor's and Master's in Computer Science** (2007–2012)
# - **Specialization:** Computer Science, Qualification: Software Engineer
#
#
# ### 💼 **Professional Experience**
#
# #### **NPK Finist-Soft, Kazan, Russia**
# **Senior C# Developer / Fintech Specialist**
# *November 2024 — Present*
# - Development of high-performance banking applications with complex business logic
# - Performance optimization for mission-critical systems
# - Leading architectural design for scalable fintech solutions
#
# #### **Kazan Federal University, Kazan, Russia**
# **Senior Lecturer in Machine Learning and Artificial Intelligence**
# *January 2022 — Present*
# - Teaching courses on Python, machine learning, deep learning, NLP, and time series analysis
# - Supervising student theses and research projects
# - Conducting research in machine learning, deep learning, and applied mathematics
#
# #### **ZAO Vitakor, Kazan, Russia**
# **Backend Developer (.NET Core) / Database Specialist**
# *July 2022 — November 2024*
# - Development and optimization of systems for the Russian Healthcare Insurance system (OMS)
# - Focus on creating automated healthcare data management systems
#
# #### **Russian-Tajik (Slavonic) University, Dushanbe, Tajikistan**
# **Associate Professor**
# *April 2018 — August 2021*
# - Teaching courses in cryptography, information security, algorithms, and OOP
# - Leading scientific research activities and supervising student research
# - Authoring textbooks and methodological guides
#
#
#
# ### 🧠 **Skills & Expertise**
#
# #### **Mathematics & Statistical Expertise**
# - Mathematical analysis, linear algebra, probability theory, and statistics
# - Differential equations, dynamical systems, and control theory
# - Numerical methods, optimization, and analytical geometry
#
#
# #### **🔬 Machine Learning & Deep Learning**
# - **Algorithms:**
#   Logistic Regression, SVM, Decision Trees, Ensemble Methods, Naive Bayes, k-NN, K-Means, DBSCAN, PCA, t-SNE, UMAP
# - **Neural Networks:**
#   CNN, RNN, LSTM, GRU, Transformer, BERT, GPT
# - **Model Optimization:**
#   Hyperparameter tuning — Grid Search, Random Search, Bayesian Optimization, Optuna
# - **ML Libraries:**
#   TensorFlow, PyTorch, Keras, Scikit-learn, XGBoost, LightGBM, CatBoost, Hugging Face Transformers, OpenCV, Statsmodels
#
#
#
# #### **🗣️ Natural Language Processing (NLP)**
# - **Core Techniques:**
#   Preprocessing, Tokenization, POS-tagging, Lemmatization
# - **Tasks:**
#   Text Classification, Sentiment Analysis, Language Modeling, Named Entity Recognition (NER), Machine Translation, Question Answering, Text Summarization, Dialogue Systems
# - **Multilingual NLP:**
#   mBERT, XLM-R
# - **Pretrained Models:**
#   RoBERTa, T5, XLNet, DistilBERT, Whisper
# - **Vectorization Techniques:**
#   Word2Vec, GloVe, FastText, TF-IDF, Byte Pair Encoding (BPE), Sentence Transformers
# - **Evaluation Metrics:**
#   BLEU, ROUGE, METEOR, Perplexity, F1-score
#
#
#
# #### **📈 Time Series Analysis**
# - **Classical Models:**
#   ARIMA, SARIMA, VAR, VARMAX, GARCH, Exponential Smoothing, Prophet
# - **Deep Learning Models:**
#   RNN (LSTM, GRU), Transformers
# - **Feature Engineering:**
#   Lag Features, Rolling Statistics, Fourier & Wavelet Transforms
# - **Cross-validation Methods:**
#   TimeSeriesSplit, Walk-Forward Validation
# - **Libraries:**
#   statsmodels, tslearn, Darts, gluonts
#
#
# #### **💻 Software Development**
# - **Programming Languages:**
#   Python, C++, C#, MATLAB, SQL, NoSQL (MongoDB, Redis, etc.)
# - **Web & Application Frameworks:**
#   FastAPI, Django, .NET Core, TensorFlow (for serving models), Flask
# - **Databases:**
#   PostgreSQL, Microsoft SQL Server (MSSQL), MongoDB, SQLite
# - **Cloud & DevOps Tools:**
#   Docker, Kubernetes, Azure DevOps, CI/CD pipelines, Git, GitHub Actions, GitLab CI, Jenkins
# - **Project & Issue Management:**
#   Jira, Trello, Confluence
# - **Development Practices:**
#   Test-Driven Development (TDD), Continuous Integration / Continuous Deployment, Agile/Scrum, SOLID principles, Design Patterns (MVC, Factory, Observer)
#
#
# ### 🏅 **Awards & Recognitions**
# - **Honored Teacher of the Ministry of Education and Science of Tajikistan** (2021)
# - **Best Paper Award** at international conferences in AI and machine learning
# - Recognized for contributions to applied mathematics and AI
#
#
#
# ### 📝 **Publications & Research**
# #### **Research Interests:**
# - Data Science, Machine Learning, Deep Learning
# - Natural Language Processing, Transfer Learning
# - Mathematical Modeling, Differential Equations
# - Optimal Control Theory and Dynamical Systems
#
# #### **Key Publications:**
# - *“Study of Periodic Solutions of Nonlinear Differential Equations”*
# - *“Deep Learning Models for Text Classification, Sentiment Analysis and Time Series Forecasting”*
#
#
#
# ### 🌟 **Personal Qualities**
# - Analytical mindset and strong attention to detail
# - High self-organization and responsibility
# - Fast learner with a strong desire for research growth
# - Team-oriented, with experience in interdisciplinary collaboration
#
#
#
# ### 👨‍🎓 **Teaching & Mentoring Experience**
#
# #### **Kazan Federal University (2022 – Present)**
# - Founded and lead the "Data Mining" club
# - Supervised over 25 students conducting research in ML, DL, NLP, and time-series forecasting
# - Received a letter of appreciation from the Rector of KFU (2025)
#
# #### **Russian-Tajik (Slavic) University (2017–2021)**
# - Mentored students who excelled in prestigious competitions, including ACM/ICPC and President's Cup
# - Graduates have interned at companies like Google, Amazon, Yandex, and VK
#
#
#
# ### 🌐 **Languages**
# - **Persian (Tajik):** Native
# - **Russian:** C1 (Advanced)
# - **English:** B1 (Intermediate)
# - **Arabic:** B1 (Reading proficiency)
#
#
#
# ### ✍️ **Additional Achievements**
# - Author of **10+ books** on programming and information security
# - Developed a web platform for NLP tasks like language modeling and classification
# - Built distributed data pipelines using Apache Spark and Kafka
#
#
#
# ## 📈 **Why KAUST?**
#
# My career has spanned several years in the Russian tech industry, where I developed large-scale automation systems for the healthcare and financial sectors. While this experience equipped me with practical and engineering-driven problem-solving skills, my enduring passion has always been in fundamental science. I now aspire to become a Doctor of Science and a professor — not only to expand the frontiers of knowledge, but to turn real-world challenges into mathematically grounded and theoretically robust solutions.
#
# My expertise lies at the intersection of **mathematical modeling, machine learning, and natural language processing** — a unique synergy that bridges theory and practice. For instance:
# - In **healthcare**, I’ve witnessed firsthand how the **absence of interpretable AI models** hinders integration into clinical workflows.
# - In **finance**, I’ve worked with **forecasting systems under data scarcity**, which motivated my interest in theoretical foundations of learning under limited information.
#
# These challenges inspire my academic goals — and **KAUST** stands out as the ideal environment to pursue them.
#
# What attracts me to KAUST:
# - 🔬 A **world-class research ecosystem** in AI, data science, and applied mathematics,
# - 🌍 A **highly interdisciplinary culture** that promotes collaboration between fields,
# - 🚀 A **focus on real-world impact**, where scientific discoveries are translated into transformative technologies.
#
# At KAUST, I am particularly eager to contribute to:
# - **Multilingual language modeling** — including LLMs for low-resource languages,
# - **Time series forecasting** — emphasizing resilience to noise and structural breaks,
# - **Deep learning theory** — such as model compression and generalization guarantees.
#
# Ultimately, my aim is not only to publish papers, but to **create scalable, scientifically grounded solutions** that bridge industry needs and academic innovation. I believe KAUST — with its outstanding infrastructure, visionary faculty, and global outlook — is the best place to make this vision a reality.
